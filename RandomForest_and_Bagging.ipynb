# %% [markdown]
# <a href="https://colab.research.google.com/github/Sai-nikhil2k5/RandomForest-and-Bagging/blob/main/RandomForest_and_Bagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree

# %%
X,y=make_classification(n_features=5,n_redundant=0,n_informative=5,random_state=1)

# %%
df=pd.DataFrame(X,columns=['c1','c2','c3','c4','c5'])
df['target']=y
print(df.head())
# Out:
#          c1        c2        c3        c4        c5  target
# 0  0.125533  0.213416 -0.963826 -0.679417 -0.502806       1
# 1 -0.286673  1.443239 -1.674176 -2.258122 -0.420532       1
# 2  0.097895  2.485946 -0.838120  0.588593  1.305518       0
# 3  2.149616  0.102549  0.556938 -1.909546 -1.620653       0
# 4 -1.649517  2.432926 -0.189314  1.849340 -2.861482       1

# %%
bag=BaggingClassifier(max_features=2)
bag.fit(X,y)
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[1])
plt.show()

# %%
rf=RandomForestClassifier(max_features=2)

# %%
rf.fit(X,y)
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[4])
plt.show()
